# %%
import requests
import json
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import csv

# %%
csv_path = r"C:\Users\erick\Projects\Project\tech_contracts\gov.contracts_info.csv"
contracts = pd.read_csv(csv_path, encoding = "ISO-8859-1")
contracts.head(10)
# Out:
#                  Contract ID  Reference IDV Modification Number  \
# 0  AE070198912DDAAE0790CJ002            NaN                   0
# 1   00011198411BSBA8456OBD84            NaN                   0
# 2   00011199007DSBA5030OBD90            NaN                   0
# 3                       0001  N6600199D5016                   0
# 4                       0001  W912JC07D5317                   0
# 5                       0001  W912JC12D5316                   0
# 6                       0002  N6600199D5016                   0
# 7                       0002  W912JC07D5317                   0
# 8                       0002  W912JC12D5316                   0
# 9                       0002  W912JC07D5317                   1
#
#    Transaction Number           Award/IDV Type Action Obligation ($)  \
# 0                   0  DCA Definitive Contract         $1,044,000.00
# 1                   0        PO Purchase Order            $41,000.00
# ...

# %%
contracts = contracts[['PSC Type', 'PSC Description','Vendor State', 'Vendor Name', 'Date Signed']]
contracts.head(10)
# Out:
#   PSC Type                                    PSC Description Vendor State  \
# 0        P                                           TRAILERS          NaN
# 1        S                   ADP SYSTEMS DEVELOPMENT SERVICES          NaN
# 2        S                            ADP DATA ENTRY SERVICES          NaN
# 3        S                PROGRAM MANAGEMENT/SUPPORT SERVICES           VA
# 4        S                         MAINT, REP/ALTER/ALL OTHER           KS
# 5        S  CONSTRUCTION OF OTHER ADMINISTRATIVE FACILITIE...           KS
# 6        S                PROGRAM MANAGEMENT/SUPPORT SERVICES           VA
# 7        S                         MAINT, REP/ALTER/ALL OTHER           KS
# 8        S         CONSTRUCTION OF OTHER INDUSTRIAL BUILDINGS           KS
# 9        S                         MAINT, REP/ALTER/ALL OTHER           KS
#
#                              Vendor Name   Date Signed
# 0                             SBA DENVER  Dec 15, 1989
# ...

# %%
state_abbrev = {
    "AL": "Alabama",
    "AK": "Alaska",
    "AZ": "Arizona",
    "AR": "Arkansas",
    "CA": "California",
    "CO": "Colorado",
    "CT": "Connecticut",
    "DE": "Delaware" ,
    "FL": "Florida",
    "GA":"Georgia" ,
    "HI": "Hawaii",
    "ID": "Idaho",
    "IL":"Illinois",
    "IN": "Indiana",
    "IA": "Iowa",
    "KS": "Kansas",
    "KY": "Kentucky",
    "LA": "Louisiana",
    "ME": "Maine",
    "MD":"Maryland",
    "MA": "Massachusetts",
    "MI": "Michigan",
    "MN": "Minnesota",
    "MS": "Mississippi",
    "MO": "Missouri",
    "MT":  "Montana",
    "NE": "Nebraska",
    "NV": "Nevada",
    "NH":"New Hampshire",
    "NJ":"New Jersey",
    "New Mexico": "NM",
    "New York": "NY",
    "NC": "North Carolina",
    "ND":"North Dakota",
    "OH": "Ohio",
    "OK": "Oklahoma",
    "OR": "Oregon",
    "PA": "Pennsylvania",
    "RI": "Rhode Island",
    "SC": "South Carolina",
    "SD": "South Dakota",
    "TN": "Tennessee" ,
    "TX": "Texas",
    "UT": "Utah",
    "VT": "Vermont",
    "VA":  "Virginia",
    "WA": "Washington",
    "WV": "West Virginia",
    "WI": "Wisconsin",
    "WY": "Wyoming"
}

# %%
state_abbrev = {abbrev: state for state, abbrev in state_abbrev.items()}
contracts['State'] = contracts['Vendor State'].map(state_abbrev)
contracts.head()
# Out:
#   PSC Type                      PSC Description Vendor State  \
# 0        P                             TRAILERS          NaN
# 1        S     ADP SYSTEMS DEVELOPMENT SERVICES          NaN
# 2        S              ADP DATA ENTRY SERVICES          NaN
# 3        S  PROGRAM MANAGEMENT/SUPPORT SERVICES           VA
# 4        S           MAINT, REP/ALTER/ALL OTHER           KS
#
#                              Vendor Name   Date Signed State
# 0                             SBA DENVER  Dec 15, 1989   NaN
# 1                                    NaN  Apr 15, 1987   NaN
# 2               SBA ADVANCE INCORPORATED  Jul 15, 1990   NaN
# 3         INTEGRATED SYSTEMS CONTROL, IN  Jan 26, 1999   NaN
# 4  SBA CONSTRUCTION COMPANY INCORPORATED  Sep 26, 2007   NaN

# %%
contracts['Vendor State']=contracts['Vendor State'].astype(str).str.upper()

# %%
#contracts_dropna=contracts[['PSC Description','Vendor State', 'Vendor Name', 'Date Signed']].dropna()
#contracts_dropna.head()

# %%
contracts_dropna=contracts[['PSC Description','State', 'Vendor Name', 'Date Signed']].dropna()
#contracts_dropna

# %%
new_df=contracts[['State','Date Signed', 'PSC Description']].dropna()
new_df
# Out:
#            State   Date Signed  \
# 1906    New York  Jul 30, 2013
# 2281  New Mexico   Sep 7, 2007
# 2282  New Mexico  Sep 12, 2007
# 2323    New York  Oct 24, 2008
# 2326    New York  Mar 30, 2016
# 2385  New Mexico  Mar 11, 2014
# 2449    New York  Apr 28, 2004
# 2450    New York  Aug 30, 2004
# 2572  New Mexico   Mar 4, 2009
# 2573  New Mexico  Feb 15, 2007
# 2574  New Mexico  Sep 13, 2007
# 2575  New Mexico  Jan 30, 2008
# 2576  New Mexico  Sep 13, 2008
# 2577  New Mexico   Jun 4, 2009
# 2578  New Mexico  Aug 28, 2009
# 2579  New Mexico  Sep 11, 2009
# 2580  New Mexico   Sep 3, 2010
# 2581  New Mexico  Sep 30, 2010
# 2582  New Mexico  Sep 18, 2008
# 2585    New York  May 12, 2005
# 2586    New York  Dec 17, 2008
# 2873  New Mexico  Mar 18, 2008
# 2874  New Mexico   Oct 1, 2006
# 2875  New Mexico  Apr 12, 2007
# 2876  New Mexico  Jul 30, 2007
# 2920  New Mexico   Nov 3, 2006
# 2921  New Mexico  Apr 11, 2007
# 2922  New Mexico  Jul 10, 2007
# 2923  New Mexico  Sep 21, 2007
# ...

# %%
x_axis = 'State'
tick_locations = [value+0.4 for value in x_axis]
plt.figure(figsize=(20,3))
plt.bar(x_axis, new_df["State"], color='blue', alpha=0.5, align="edge")
plt.xticks(new_df['PSC Description', new_df["State"], rotation="vertical")
# Out:
#   File "<ipython-input-33-8a554a0b7d29>", line 5
#     plt.xticks(new_df['PSC Description', new_df["State"], rotation="vertical")
#                                                                   ^
# SyntaxError: invalid syntax

# %%
#contracts = pd.DataFrame({'PSC Description','Vendor State','Vendor Name','Date Signed'})
#df.rename(columns={'PSC Description': 'Business Type', 'Vendor State': 'State', 'Vendor Name':'Business Name',\
                   'Date Signed':'Date Signed'})

# %%
# Remove projects that made no money at all
#reduced_kickstarter_df = reduced_kickstarter_df.loc[(reduced_kickstarter_df["pledged"] > 0)]
#reduced_kickstarter_df.head()
# Create a list of the columns
#columns = ['PSC Description','Business Type', 'Vendor State', 'Vendor Name',
                   'Date Signed']
   
#  Create a new df for "US" with the columns. 
#state = pd.DataFrame[contracts,  columns]
#state.head()

# %%
# Use Map to format all the columns
#file_df["avg_cost"] = file_df["avg_cost"].map("${:.4f}".format)
#file_df["population"] = file_df["population"].map("{:,}".format)
#file_df["other"] = file_df["other"].map("{:.2f}".format)
#file_df.head()

# %%
#contracts_df = pd.DataFrame({"": [PSC Type, , 3], "B": [4, 5, 6]})
#df.rename(columns={"A": "a", "B": "c"})

# %%
csv_path = r"C:\Users\erick\Projects\Project\tech_contracts\Unemployment_rate_per_state.csv"
unemployment_rate = pd.read_csv(csv_path, encoding = "ISO-8859-1")
unemployment_rate.head()

# %%
unemployment_rate['State']=unemployment_rate['State'].apply(lambda x:x.upper())
unemployment_rate.head()

# %%
#average=state_unemployment.mean
#average_df=pd.DataFrame({average, "State": [:]})

# %%
state_unemployment= pd.merge(average, new_df, on='State', how='outer')
state_unemployment
#unemployment_rate.dtypes

# %%
#average = unemployment_rate.mean
#average

# %%
x_axis = 'State'
tick_locations = [value+0.4 for value in x_axis]

# %%
plt.figure(figsize=(20,3))
plt.bar(x_axis, contracts_dropna["State"], color='blue', alpha=0.5, align="edge")
plt.xticks(average, contracts_dropna["State"], rotation="vertical")

# %%
csv_path = r"C:/Users/erick/Projects/Project/tech_contracts/GDP_by_State.csv"
gdp_state = pd.read_csv(csv_path, encoding = "ISO-8859-1")
gdp_state.head()
# Out:
#          Area  2000 ($MM)   2005 ($MM)   2010 ($MM)   2015 ($MM)   \
# 0     Alabama    $119,020     $156,750     $174,710     $199,656
# 1      Alaska     $26,853      $40,063      $54,134      $52,747
# 2     Arizona    $165,912     $227,358     $245,668     $290,903
# 3    Arkansas     $68,809      $90,319     $102,951     $118,907
# 4  California  $1,362,995   $1,766,693   $1,965,886   $2,481,348
#
#   2000 % of Total 2015 % of Total 2000-15 Compound Growth Rate  \
# 0           1.16%           1.11%                        3.51%
# 1           0.26%           0.29%                        4.60%
# 2           1.62%           1.62%                        3.81%
# 3           0.67%           0.66%                        3.71%
# 4          13.34%          13.85%                        4.07%
#
#    Growth Rate Rank Change in % 2000-15
# 0              35.0              -0.05%
# 1              10.0               0.03%
# 2              22.0               0.00%
# ...

# %%
gdp_state['Area'].astype(str).str.upper()

#gdp_state['Area']= gdp_state['Area']).upper()
#gdp_state.head()

# %%
gdp_state['Area']=gdp_state['Area'].astype(str).str.upper()
gdp_state.head()
# Out:
#          Area  2000 ($MM)   2005 ($MM)   2010 ($MM)   2015 ($MM)   \
# 0     ALABAMA    $119,020     $156,750     $174,710     $199,656
# 1      ALASKA     $26,853      $40,063      $54,134      $52,747
# 2     ARIZONA    $165,912     $227,358     $245,668     $290,903
# 3    ARKANSAS     $68,809      $90,319     $102,951     $118,907
# 4  CALIFORNIA  $1,362,995   $1,766,693   $1,965,886   $2,481,348
#
#   2000 % of Total 2015 % of Total 2000-15 Compound Growth Rate  \
# 0           1.16%           1.11%                        3.51%
# 1           0.26%           0.29%                        4.60%
# 2           1.62%           1.62%                        3.81%
# 3           0.67%           0.66%                        3.71%
# 4          13.34%          13.85%                        4.07%
#
#    Growth Rate Rank Change in % 2000-15
# 0              35.0              -0.05%
# 1              10.0               0.03%
# 2              22.0               0.00%
# ...

# %%
#gdp_state = pd.DataFrame({"": [1, 2, 3], "B": [4, 5, 6]})
gdp_state.rename(columns={"Area":"State"},inplace = True)

# %%
gdp_merge = pd.merge(gdp_state, new_df, on='State', how= 'outer')
gdp_merge.head(100)
# Out:
#                    State  2000 ($MM)   2005 ($MM)   2010 ($MM)   2015 ($MM)   \
# 0                ALABAMA    $119,020     $156,750     $174,710     $199,656
# 1                 ALASKA     $26,853      $40,063      $54,134      $52,747
# 2                ARIZONA    $165,912     $227,358     $245,668     $290,903
# 3               ARKANSAS     $68,809      $90,319     $102,951     $118,907
# 4             CALIFORNIA  $1,362,995   $1,766,693   $1,965,886   $2,481,348
# 5               COLORADO    $181,488     $220,454     $253,374     $313,748
# 6            CONNECTICUT    $169,004     $210,170     $234,528     $252,930
# 7               DELAWARE     $44,851      $53,247      $57,471      $68,724
# 8   DISTRICT OF COLUMBIA     $60,059      $83,586     $103,831     $122,146
# 9                FLORIDA    $497,541     $700,267     $735,098     $888,087
# 10               GEORGIA    $306,528     $388,342     $412,485     $497,944
# ...

# %%
plt.figure(figsize=(20,3))
plt.bar(x_axis, gdp_merge["State"], color='blue', alpha=0.5, align="edge")
plt.xticks(gdp_merge, gdp_merge["Growth Rate Rank"], rotation="vertical")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-c581feba27d5> in <module>
#       1 plt.figure(figsize=(20,3))
# ----> 2 plt.bar(x_axis, gdp_merge["State"], color='blue', alpha=0.5, align="edge")
#       3 plt.xticks(gdp_merge, gdp_merge["Growth Rate Rank"], rotation="vertical")
#
# NameError: name 'x_axis' is not defined
